# %% [markdown]
# # Importing Libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
import pathlib
import cv2
from tensorflow.keras import layers
from sklearn.model_selection import KFold, StratifiedKFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import glob
import csv
import numpy as np
import joblib

# %% [markdown]
# # Preparing dataset

# %%
#path_data = '../input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset'
path_test = '../Dataset/Brain-tumor/Testing/'
path_data = '../Dataset/Brain-tumor/Training/'


path_test = pathlib.Path(path_test)
path_data = pathlib.Path(path_data)
print(path_data)

image_count = len(list(path_data.glob('*/*.jpg')))
print(image_count)
# Out:
# ..\Dataset\Brain-tumor\Training
# 5712

# %% [markdown]
# #### Image of a brain with tumor

# %% [markdown]
# ### Creating Testing Validation and Testing Sets

# %%
batch = 32
img_height = 180
img_width = 180

# %%
train = tf.keras.preprocessing.image_dataset_from_directory(
path_data,
validation_split = 0.2,
subset = 'training',
seed = 42,
image_size  =(img_height,img_width),
batch_size = batch)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.

# %%
val = tf.keras.preprocessing.image_dataset_from_directory(
path_data,
validation_split = 0.2,
subset = 'validation',
seed = 42,
image_size = (img_height,img_width),
batch_size = batch)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
test = tf.keras.preprocessing.image_dataset_from_directory(
path_test,
seed = 42,
image_size = (img_height,img_width),
batch_size = batch)
# Out:
# Found 1311 files belonging to 4 classes.

# %%
print(train.class_names)
print(val.class_names)
print(test.class_names)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
classes = train.class_names
plt.figure(figsize = (10,10))
for img,label in train.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(img[i].numpy().astype("uint8"))
        plt.title(classes[label[i]],
                  fontdict = {'fontsize': '19',
                              'color': 'white'}
                 )

# %%
for image_batch, labels_batch in train:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train = train.prefetch(buffer_size=AUTOTUNE)
val = val.prefetch(buffer_size=AUTOTUNE)
test = test.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Helper Functions
# <a id='helper'></a>

# %%
def test_tumor(list_test_path,model):
    for path_name in list_test_path:
        test_img_path = path_name


        test_image = tf.keras.preprocessing.image.load_img(
            test_img_path, target_size=(img_height, img_width)
        )
        test_array = tf.keras.preprocessing.image.img_to_array(test_image)
        test_array = tf.expand_dims(test_array, 0) # Create a batch

        predictions = model.predict(test_array)
        score = tf.nn.softmax(predictions[0])

        print(
            "This image most likely belongs to {} with a {:.2f} percent confidence."
            .format(classes[np.argmax(score)], 100 * np.max(score))
        )

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
conv_layer_32 = tf.keras.layers.Conv2D(32,(3,3),activation='relu')
conv_layer_64 = tf.keras.layers.Conv2D(64,3,activation='relu')
conv_layer_16 = tf.keras.layers.Conv2D(16,3,activation='relu')
max_pool = tf.keras.layers.MaxPooling2D()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1),
  ]
)

# %% [markdown]
# # Model Building

# %%
num_classes = 4

model = tf.keras.Sequential([
  normalization_layer,
  conv_layer_32,
  max_pool,
  conv_layer_32,
  max_pool,
  conv_layer_32,
  max_pool,
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
# e.g. for 4 classes
num_classes = 4

model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(180, 180, 3)),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(16, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(num_classes)  # No activation since using logits
])

# Keep SparseCategoricalCrossentropy
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)


# Fit model
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

history = model.fit(
    train,
    validation_data=val,
    epochs=3,
    callbacks=[callback]
)

# Print how many effective epochs were run
eff_epochs = len(history.history['loss'])
print(f"Effective epochs run: {eff_epochs}")
# Out:
# Epoch 1/3
# c:\Users\mayank.c\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 110s 755ms/step - accuracy: 0.5917 - loss: 0.9243 - val_accuracy: 0.7356 - val_loss: 0.6897
# Epoch 2/3
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 75s 524ms/step - accuracy: 0.8225 - loss: 0.4412 - val_accuracy: 0.8669 - val_loss: 0.3625
# Epoch 3/3
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 77s 536ms/step - accuracy: 0.8939 - loss: 0.2893 - val_accuracy: 0.9098 - val_loss: 0.2718
# Effective epochs run: 3

# %%
joblib.dump(model, '../Models/bt-cnn.joblib')
# Out:
# ['../Models/bt-cnn.joblib']

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = 10

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(eff_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy',fontdict = {'fontsize': '14',
                              'color': 'white'})

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss',fontdict = {'fontsize': '14',
                              'color': 'white'})
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 41, 41, 16)     │         9,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 20, 20, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │       409,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,315,646 (5.02 MB)
#  Trainable params: 438,548 (1.67 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 877,098 (3.35 MB)

# %%
results = model.evaluate(test)
print("test loss, test acc:", results)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 18s 438ms/step - accuracy: 0.9018 - loss: 0.3061
# test loss, test acc: [0.30299898982048035, 0.8962624073028564]

# %%
list_of_paths = ['../Dataset/Brain-tumor/Testing/pituitary/Te-piTr_0007.jpg',
                '../Dataset/Brain-tumor/Testing/notumor/Te-noTr_0000.jpg',
                '../Dataset/Brain-tumor/Testing/meningioma/Te-meTr_0004.jpg',
                '../Dataset/Brain-tumor/Testing/glioma/Te-glTr_0007.jpg']
test_tumor(list_of_paths,model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# This image most likely belongs to pituitary with a 92.34 percent confidence.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# This image most likely belongs to notumor with a 56.64 percent confidence.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# This image most likely belongs to meningioma with a 90.80 percent confidence.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# This image most likely belongs to glioma with a 99.68 percent confidence.

# %% [markdown]
# # Second Model

# %% [markdown]
# Adding a data augmentation layer to add more images to the training data by simply modifying the existing images in ways such as flipping them or making similar random transformations to the training data.

# %%
num_classes = 4

model2 = tf.keras.Sequential([
  #data_augmentation,
  normalization_layer,
  #tf.keras.layers.Conv2D(32,3,activation='relu'),
  conv_layer_32,
  layers.MaxPooling2D(pool_size=(2,2)),
  conv_layer_32,
  layers.MaxPooling2D(pool_size=(2,2)),
  layers.Flatten(),
  layers.Dense(32, activation='relu'),
  layers.Dropout(0.25),
  layers.Dense(num_classes,activation='softmax')
])

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 5
history = model2.fit(
  train,
  validation_data=val,
  epochs=epochs,
  callbacks = callback,
  shuffle=False
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 epochs = 5
# ----> 2 history = model2.fit(
#       3   train,
#       4   validation_data=val,
#       5   epochs=epochs,
#       6   callbacks = callback,
#       7   shuffle=False
#       8 )
#
# File c:\Users\mayank.c\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\mayank.c\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\input_spec.py:227, in assert_input_compatibility(input_spec, inputs, layer_name)
#     222     for axis, value in spec.axes.items():
#     223         if value is not None and shape[axis] not in {
#     224             value,
#     225             None,
#     226         }:
# --> 227             raise ValueError(
#     228                 f'Input {input_index} of layer "{layer_name}" is '
#     229                 f"incompatible with the layer: expected axis {axis} "
#     230                 f"of input shape to have value {value}, "
#     231                 "but received input with "
#     232                 f"shape {shape}"
#     233             )
#     234 # Check shape.
#     235 if spec.shape is not None:
#
# ValueError: Input 0 of layer "conv2d" is incompatible with the layer: expected axis -1 of input shape to have value 3, but received input with shape (None, 89, 89, 32)

# %%
joblib.dump(model2, '../Models/bt-cnn2.joblib')
# Out:
# ['../Models/bt-cnn2.joblib']

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d_1 (MaxPoolin  (None, 89, 89, 32)        0
#  g2D)
#
#  max_pooling2d_2 (MaxPoolin  (None, 44, 44, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_2 (Dense)             (None, 32)                1982496
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 1983524 (7.57 MB)
# Trainable params: 1983524 (7.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
eff_epochs = len(history.history['loss'])
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = 10

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(eff_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy',fontdict = {'fontsize': '14',
                              'color': 'black'})

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss',fontdict = {'fontsize': '14',
                              'color': 'black'})
plt.show()

# %%
results = model2.evaluate(test)
print("test loss, test acc:", results)
# Out:
# 41/41 [==============================] - 3s 65ms/step - loss: 0.2323 - accuracy: 0.9314
# test loss, test acc: [0.23233157396316528, 0.9313501119613647]

# %% [markdown]
# ## Third Model
# ### Using a pretrained model: MobileNetV2

# %%
# Create the base model from the pre-trained model MobileNet V2
image_size = (img_width,img_height)
IMG_SHAPE = image_size + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

base_model.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 4s 0us/step

# %%
image_batch, label_batch = next(iter(train))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 6, 6, 1280)

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 90, 90, 32)           864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 90, 90, 32)           128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 90, 90, 32)           0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 90, 90, 32)           288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 90, 90, 32)           128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 90, 90, 32)           0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 90, 90, 16)           512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 90, 90, 16)           64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 90, 90, 96)           1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 90, 90, 96)           384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 90, 90, 96)           0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 91, 91, 96)           0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 45, 45, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 45, 45, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 45, 45, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 45, 45, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 45, 45, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 45, 45, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 45, 45, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 45, 45, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 45, 45, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 45, 45, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 45, 45, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 45, 45, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 45, 45, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 45, 45, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 45, 45, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 45, 45, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 45, 45, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 47, 47, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 23, 23, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 23, 23, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 23, 23, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 23, 23, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 23, 23, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 23, 23, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 23, 23, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 23, 23, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 23, 23, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 23, 23, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 23, 23, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 23, 23, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 23, 23, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 23, 23, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 23, 23, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 23, 23, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 23, 23, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 23, 23, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 23, 23, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 23, 23, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 23, 23, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 23, 23, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 23, 23, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 23, 23, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 23, 23, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 23, 23, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 25, 25, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 12, 12, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 12, 12, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 12, 12, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 12, 12, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 12, 12, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 12, 12, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 12, 12, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 12, 12, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 12, 12, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 12, 12, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 12, 12, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 12, 12, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 12, 12, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 12, 12, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 12, 12, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 12, 12, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 12, 12, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 12, 12, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 12, 12, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 12, 12, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 12, 12, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 12, 12, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 12, 12, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 12, 12, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 12, 12, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 12, 12, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 12, 12, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 12, 12, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 12, 12, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 12, 12, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 12, 12, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 12, 12, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 12, 12, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 12, 12, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 12, 12, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 12, 12, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 12, 12, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 12, 12, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 12, 12, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 12, 12, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 12, 12, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 12, 12, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 12, 12, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 12, 12, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 12, 12, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 12, 12, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 12, 12, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 12, 12, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 12, 12, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 12, 12, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 12, 12, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 12, 12, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 12, 12, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 12, 12, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 12, 12, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 12, 12, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 12, 12, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 12, 12, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 12, 12, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 12, 12, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 12, 12, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 13, 13, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 6, 6, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 6, 6, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 6, 6, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 6, 6, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 6, 6, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 6, 6, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 6, 6, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 6, 6, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 6, 6, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 6, 6, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 6, 6, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 6, 6, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 6, 6, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 6, 6, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 6, 6, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 6, 6, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 6, 6, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 6, 6, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 6, 6, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 6, 6, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 6, 6, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 6, 6, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 6, 6, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 6, 6, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 6, 6, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 6, 6, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 6, 6, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 6, 6, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 6, 6, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 6, 6, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 6, 6, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 6, 6, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 6, 6, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 6, 6, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(4)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (32, 4)

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
inputs = tf.keras.Input(shape=(180, 180, 3))
#x = data_augmentation(inputs)
x = preprocess_input(inputs)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(1280,activation='relu')(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
len(model.trainable_variables)
# Out:
# 4

# %%
initial_epochs = 5

loss0, accuracy0 = model.evaluate(val)
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# 36/36 [==============================] - 12s 338ms/step - loss: 0.2644 - accuracy: 0.9037
# initial loss: 0.26
# initial accuracy: 0.90

# %%
history_base = model.fit(train,
                         epochs=initial_epochs,
                         validation_data=val,
                         shuffle=False
                        )
# Out:
# Epoch 1/5
# 143/143 [==============================] - 59s 415ms/step - loss: 0.2706 - accuracy: 0.9004 - val_loss: 0.2557 - val_accuracy: 0.8993
# Epoch 2/5
# 143/143 [==============================] - 63s 438ms/step - loss: 0.2100 - accuracy: 0.9232 - val_loss: 0.2311 - val_accuracy: 0.9098
# Epoch 3/5
# 143/143 [==============================] - 65s 449ms/step - loss: 0.1768 - accuracy: 0.9278 - val_loss: 0.2582 - val_accuracy: 0.9124
# Epoch 4/5
# 143/143 [==============================] - 55s 385ms/step - loss: 0.1503 - accuracy: 0.9438 - val_loss: 0.2014 - val_accuracy: 0.9291
# Epoch 5/5
# 143/143 [==============================] - 57s 396ms/step - loss: 0.1281 - accuracy: 0.9479 - val_loss: 0.2442 - val_accuracy: 0.9247

# %%
joblib.dump(model, '../Models/bt-mobilenet.joblib')
# Out:
# ['../Models/bt-mobilenet.joblib']

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 180, 180, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 180, 180, 3)       0
#  da)
#
#  mobilenetv2_1.00_224 (Func  (None, 6, 6, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  flatten_2 (Flatten)         (None, 1280)              0
#
#  dense_5 (Dense)             (None, 1280)              1639680
#
#  dense_4 (Dense)             (None, 4)                 5124
#
# =================================================================
# Total params: 3902788 (14.89 MB)
# Trainable params: 1644804 (6.27 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
acc = history_base.history['accuracy']
val_acc = history_base.history['val_accuracy']

loss = history_base.history['loss']
val_loss = history_base.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy',fontdict = {'fontsize': '14',
                              'color': 'white'})

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')


plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss',fontdict = {'fontsize': '14',
                              'color': 'white'})
plt.xlabel('epoch')
plt.show()

# %%
result = model.evaluate(test)
print(result)
# Out:
# 41/41 [==============================] - 15s 351ms/step - loss: 0.2543 - accuracy: 0.9222
# [0.2542831003665924, 0.9221968054771423]
